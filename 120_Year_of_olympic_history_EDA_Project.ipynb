# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('athlete_events.csv')

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
data.sample(5)
# Out:
#             ID                      Name Sex   Age  Height  Weight     Team  \
# 138168   69420                     Li Ju   F  24.0   164.0    53.0    China
# 77950    39583          Ramiro Georgescu   M  29.0   193.0    93.0  Romania
# 200047  100474              Yvan Richard   M  21.0   165.0    60.0   France
# 186063   93547       Giovanni Perricelli   M  28.0   175.0    70.0    Italy
# 32354    16629  Olena Ivanivna Burkovska   F  30.0   158.0    50.0  Ukraine
#
#         NOC        Games  Year  Season     City         Sport  \
# 138168  CHN  2000 Summer  2000  Summer   Sydney  Table Tennis
# 77950   ROU  2012 Summer  2012  Summer   London    Water Polo
# 200047  FRA  1972 Winter  1972  Winter  Sapporo   Ski Jumping
# 186063  ITA  1996 Summer  1996  Summer  Atlanta     Athletics
# 32354   UKR  2012 Summer  2012  Summer   London     Athletics
#
#                                            Event   Medal
# 138168              Table Tennis Women's Singles  Silver
# ...

# %%
data.shape
# Out:
# (271116, 15)

# %%
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data['Age']= data['Age'].fillna(data['Age'].mean())
data['Height']= data['Height'].fillna(data['Height'].mean())
data['Weight']= data['Weight'].fillna(data['Weight'].mean())

# %%
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height         0
# Weight         0
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     271116 non-null  float64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
data.describe()
# Out:
#                   ID            Age        Height         Weight  \
# count  271116.000000  271116.000000  271116.00000  271116.000000
# mean    68248.954396      25.556898     175.33897      70.702393
# std     39022.286345       6.280857       9.27810      12.574690
# min         1.000000      10.000000     127.00000      25.000000
# 25%     34643.000000      22.000000     170.00000      63.000000
# 50%     68205.000000      25.000000     175.33897      70.702393
# 75%    102097.250000      28.000000     180.00000      75.000000
# max    135571.000000      97.000000     226.00000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data.duplicated().sum()
# Out:
# 1385

# %%
data[data.duplicated()]
# Out:
#             ID                                 Name Sex   Age     Height  \
# 1252       704                   Dsir Antoine Acket   M  27.0  175.33897
# 4282      2449               William Truman Aldrich   M  48.0  175.33897
# 4283      2449               William Truman Aldrich   M  48.0  175.33897
# 4862      2777               Hermann Reinhard Alker   M  43.0  175.33897
# 4864      2777               Hermann Reinhard Alker   M  43.0  175.33897
# ...        ...                                  ...  ..   ...        ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  175.33897
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  175.33897
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0  175.33897
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)   F  49.0  175.33897
# 270200  135173                     Henri Achille Zo   M  58.0  175.33897
#
#            Weight           Team  NOC        Games  Year  Season         City  \
# ...

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#             ID                      Name Sex   Age     Height     Weight  \
# 0            1                 A Dijiang   M  24.0  180.00000  80.000000
# 1            2                  A Lamusi   M  23.0  170.00000  60.000000
# 2            3       Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393
# 3            4      Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 4            5  Christine Jacoba Aaftink   F  21.0  185.00000  82.000000
# ...        ...                       ...  ..   ...        ...        ...
# 271111  135569                Andrzej ya   M  29.0  179.00000  89.000000
# 271112  135570                  Piotr ya   M  27.0  176.00000  59.000000
# 271113  135570                  Piotr ya   M  27.0  176.00000  59.000000
# 271114  135571        Tomasz Ireneusz ya   M  30.0  185.00000  96.000000
# 271115  135571        Tomasz Ireneusz ya   M  34.0  185.00000  96.000000
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
numerical_data=data.select_dtypes(include=['number'])

# %%
numerical_data.corr()
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.002825 -0.009791 -0.008059  0.011381
# Age    -0.002825  1.000000  0.111115  0.168071 -0.088250
# Height -0.009791  0.111115  1.000000  0.786635  0.030126
# Weight -0.008059  0.168071  0.786635  1.000000  0.011598
# Year    0.011381 -0.088250  0.030126  0.011598  1.000000

# %%
sns.heatmap(numerical_data.corr())
# Out:
# <Axes: >

# %%
data.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
data['Sex'].value_counts()
# Out:
# Sex
# M    195353
# F     74378
# Name: count, dtype: int64

# %%
gen_dist = data['Sex'].value_counts()
plt.figure(figsize=(5,3))
sns.barplot(x=gen_dist.index,y=gen_dist.values)
plt.title('Gender Distribution in the olympics')
plt.xlabel('Gender')
plt.ylabel('count')
plt.show()

# %%
gen_dist.values
# Out:
# array([195353,  74378], dtype=int64)

# %%
gen_dist.index
# Out:
# Index(['M', 'F'], dtype='object', name='Sex')

# %%
top=data['Sport'].value_counts().head(10)
plt.figure(figsize=(5,3))
sns.barplot(x=top.values,y=top.index)
plt.title('Top 10 sports by participation')
plt.xlabel('No.of Athletes')
plt.ylabel('sport')
plt.show()

# %%
top
# Out:
# Sport
# Athletics               38624
# Gymnastics              26707
# Swimming                23195
# Shooting                11448
# Cycling                 10827
# Fencing                 10735
# Rowing                  10595
# Cross Country Skiing     9133
# Alpine Skiing            8829
# Wrestling                7154
# Name: count, dtype: int64

# %%
top=data['Sport'].value_counts().head(10).plot(kind='pie',autopct="%1.2f%%")

# %%
data['Sport'].value_counts()
# Out:
# Sport
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10827
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: count, Length: 66, dtype: int64

# %%
data['Sport'].value_counts().idxmax()
# Out:
# 'Athletics'

# %% [markdown]
# NUmerical Data

# %%
data.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %% [markdown]
# #####1.check the distribution of age#####

# %%
sns.histplot(data['Age'],bins=20,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x=data['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
data['Age'].min()
# Out:
# 10.0

# %%
data['Age'].max()
# Out:
# 97.0

# %%
data['Age'].mean()
# Out:
# 25.458302932173996

# %%
data['Age'].skew()#in histplot the line represents skew if rhs its +ve & lhs is _ve
# Out:
# 1.5877141959478527

# %% [markdown]
#  Bivarite and mutlivate analsis
#  # Bivariate = taking 2 columns or attributes
#  #multi= taking 2 or more for analysis...

# %% [markdown]
# 1. numerical-numerical relationship

# %%
sns.scatterplot(x='Age',y='Height',data=data )
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.scatterplot(x='Age',y='Height',hue='Sex' ,data=data )
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %% [markdown]
# 2. num-categorical relationship(age distribution by medal type)

# %%
data.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
sns.barplot(x='Medal',y='Age',data=data)
# Out:
# <Axes: xlabel='Medal', ylabel='Age'>

# %%
sns.boxplot(x='Medal',y='Age',hue='Sex',data=data)
# Out:
# <Axes: xlabel='Medal', ylabel='Age'>

# %% [markdown]
# 3. cate-cate relationship

# %% [markdown]
# how many gold,silver,bronze medals medals have been awarded to male and female athletes

# %%
con = pd.crosstab(data['Sex'],data['Medal'])

# %%
con
# Out:
# Medal  Bronze  Gold  Silver
# Sex
# F        3771  3747    3735
# M        9524  9622    9373

# %%
sns.heatmap(pd.crosstab(data['Sex'],data['Medal']))
# Out:
# <Axes: xlabel='Medal', ylabel='Sex'>

# %% [markdown]
# #num-num
# #display medal performance for a specific country per year

# %%
data.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
data["Team"]
# Out:
# 0                  China
# 1                  China
# 2                Denmark
# 3         Denmark/Sweden
# 4            Netherlands
#                ...
# 271111          Poland-1
# 271112            Poland
# 271113            Poland
# 271114            Poland
# 271115            Poland
# Name: Team, Length: 269731, dtype: object

# %%
df=data[data["Team"]=='India']

# %%
india=df.groupby('Year')['Medal'].count()

# %%
india
# Out:
# Year
# 1900     2
# 1920     0
# 1924     7
# 1928    14
# 1932    15
# 1936    19
# 1948    20
# 1952    15
# 1956    17
# 1960    13
# 1964    15
# 1968    16
# 1972    14
# 1976     0
# 1980    16
# 1984     0
# 1988     0
# 1992     0
# 1996     1
# 1998     0
# 2000     1
# 2002     0
# 2004     1
# 2006     0
# 2008     3
# 2010     0
# 2012     6
# 2014     0
# 2016     2
# Name: Medal, dtype: int64

# %%
india.index
# Out:
# Index([1900, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968,
#        1972, 1976, 1980, 1984, 1988, 1992, 1996, 1998, 2000, 2002, 2004, 2006,
#        2008, 2010, 2012, 2014, 2016],
#       dtype='int64', name='Year')

# %%
india.values
# Out:
# array([ 2,  0,  7, 14, 15, 19, 20, 15, 17, 13, 15, 16, 14,  0, 16,  0,  0,
#         0,  1,  0,  1,  0,  1,  0,  3,  0,  6,  0,  2], dtype=int64)

# %%
sns.lineplot(x=india.index,y=india.values)
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # Numerical - Categorical Relationships

# %% [markdown]
# Display the top 10 athletes by medals won

# %%
data.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
medal_counts=data['Name'].value_counts().reset_index()

# %%
medal_counts.columns=['Athlete','Medal_count']

# %%
sns.barplot(x='Medal_count',y='Athlete',data=medal_counts.head(10))
# Out:
# <Axes: xlabel='Medal_count', ylabel='Athlete'>

# %% [markdown]
# find and display the count of medals (bronze silver gold )  won in each city and present the result in a table format

# %%
data.groupby(['City','Medal']).size().unstack()
# Out:
# Medal                   Bronze  Gold  Silver
# City
# Albertville                106   104     108
# Amsterdam                  250   245     239
# Antwerpen                  367   493     448
# Athina                     860   883     859
# Atlanta                    629   608     605
# Barcelona                  604   559     549
# Beijing                    710   671     667
# Berlin                     295   312     310
# Calgary                     88    87      88
# Chamonix                    37    55      38
# Cortina d'Ampezzo           50    51      49
# Garmisch-Partenkirchen      35    36      37
# Grenoble                    63    66      70
# Helsinki                   300   306     291
# Innsbruck                  128   131     138
# Lake Placid                101   104     105
# Lillehammer                112   110     109
# London                    1214  1215    1195
# Los Angeles                706   726     691
# Melbourne                  286   290     281
# ...

# %% [markdown]
# sort the medal counts per city based on the total number of medals (bronze silver gold)

# %%
medal=data.groupby(['City','Medal']).size().unstack()

# %%
medal['Total']=medal[['Bronze','Silver','Gold']].sum(axis=1)

# %%
medal.sort_values(by='Total',ascending=False)
# Out:
# Medal                   Bronze  Gold  Silver  Total
# City
# London                    1214  1215    1195   3624
# Athina                     860   883     859   2602
# Los Angeles                706   726     691   2123
# Beijing                    710   671     667   2048
# Rio de Janeiro             703   665     655   2023
# Sydney                     680   663     661   2004
# Atlanta                    629   608     605   1842
# Barcelona                  604   559     549   1712
# Seoul                      549   520     513   1582
# Paris                      449   475     501   1425
# Moskva                     469   457     458   1384
# Montreal                   448   438     434   1320
# Antwerpen                  367   493     448   1308
# Munich                     419   404     392   1215
# Mexico City                358   359     340   1057
# Tokyo                      343   347     339   1029
# Stockholm                  312   338     327    977
# ...
